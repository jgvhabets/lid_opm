# %% [markdown]
# ## Welcome to this coding exercise!
#
# Take your time, up to 2 hours, and send us back this notebook, showing how you solved and visualized the following challenge.

# %% [markdown]
# ### Challenge
# We recorded electrophysiology data and accelerometer data during a self-paced hand tapping task. We are interested in the spectral differences between the moments where the patient moved, and the movement where they did not move.
#
# #### Tips
# - recommend packages: `numpy`, `scipy`, `pandas`, `matplotlib`, but no need to you use these!
# - acc and ephys do not have the same sampling frequency
# - figure out pragmatically how many movements where performed, you can choose to pragmatically define every half a second after movement onset as "movement"
# - "dopa_time" refers to the overall time in the protocol
# - perform a time-frequency-decomposition using a bipolar signal subtracting "LFP_R_01" from "LFP_R_01"
# - describe frequencies below 50 Hz
#
# #### Important
# Make sure to comment sufficiently, so we can understand what and why you are doing!
