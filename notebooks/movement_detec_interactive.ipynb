# %%
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import utils.find_paths as find_paths
import combined_analysis_bachelor.code.read_in_emg_acc as read_in
import combined_analysis_bachelor.code.movement_detection_functions as move_functions
import combined_analysis_bachelor.code.create_processed_files as process
import combined_analysis_bachelor.code.functions_for_pipeline as funcs
import utils.get_sub_dir as get_sub_dir
from utils.get_sub_dir import get_sub_folder_dir

# %%
importlib.reload(get_sub_dir)
importlib.reload(find_paths)
importlib.reload(move_functions)
importlib.reload(process)
importlib.reload(funcs)
# Out:
# <module 'combined_analysis_bachelor.code.functions_for_pipeline' from 'C:\\Users\\User\\Documents\\GitHub\\lid_opm\\combined_analysis_bachelor\\code\\functions_for_pipeline.py'>

# %%
SUB = 91
SF= 1000
fig_dir = get_sub_dir.get_sub_folder_dir(SUB, "figures")
fig_dir = f"{fig_dir}/plots_from_interactive_detec"

processed_data_path = find_paths.get_onedrive_path("onedrive_charite", "processed_data")
sub91_filepaths, processed_files = read_in.show_processed_data(sub=SUB, processed_paths=processed_data_path)

out_dir = get_sub_dir.get_sub_folder_dir(SUB, "onset_data")
out_dir = f"{out_dir}/sub-{SUB}_movement_detec_jsons"

baselines = {
    "arm_L_setupA_Move1": [10,20],
    "arm_R_setupA_Move1": [10,20],
    "arm_L_setupA_Move2": [10,15],
    "arm_R_setupA_Move2": [10,15],
    "arm_L_setupA_MoveMockDys": [3,13],
    "arm_R_setupA_MoveMockDys": [8,14],
    "arm_L_setupA_Rest": [10,30],
    "arm_R_setupA_Rest": [10,30],
    "arm_L_setupA_RestMockDys": [10,30],
    "arm_R_setupA_RestMockDys": [10,30],
    "arm_L_setupB_Move": [12,16],
    "leg_L_setupB_Move": [12,15],
    "arm_L_setupB_MoveMockDys": [10,15],
    "leg_L_setupB_MoveMockDys": [10,15],
    "arm_L_setupB_Rest": [10,20],
    "leg_L_setupB_Rest": [10,20],
    "arm_L_setupB_RestMockDys": [20,30],
    "leg_L_setupB_RestMockDys": [20,30]
}
# Out:
# project folder found: C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG
# C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG\figures
# project folder found: C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG
# project folder found: C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG
# C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG\data\onset_data

# %%
#process.create_processed_files(raw_dir, proc_dir, [1,20], [20,450], 1000)

# %%
move_functions.interactive_move_detection(sub91_filepaths, out_dir, fig_dir, SF, baseline_dict=baselines)
# Out:
# [PNG DEBUG] Subplot-BBox (inches): 15.44 x 4.69
# [PNG] gespeichert (nur Subplots): C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG\figures\sub-91\EMG_ACC/plots_from_interactive_detec\sub-91_setupA_Move1_armL.png
# [PNG DEBUG] Subplot-BBox (inches): 9.86 x 5.04
# [PNG] gespeichert (nur Subplots): C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG\figures\sub-91\EMG_ACC/plots_from_interactive_detec\sub-91_setupA_Move1_armR.png
# [OK] JSON Gespeichert: C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG\data\onset_data\sub-91\EMG_ACC/sub-91_movement_detec_jsons\sub-91_EmgAcc_setupA_Move1.json
# [PNG DEBUG] Subplot-BBox (inches): 9.86 x 5.04
# [PNG] gespeichert (nur Subplots): C:\Users\User\OneDrive - Charité - Universitätsmedizin Berlin\TRR295 via Teams - LID_MEG - LID_MEG\figures\sub-91\EMG_ACC/plots_from_interactive_detec\sub-91_setupA_Move2_armL.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 move_functions.interactive_move_detection(sub91_filepaths, out_dir, fig_dir, SF, baseline_dict=baselines)
#
# File ~\Documents\GitHub\lid_opm\combined_analysis_bachelor\code\movement_detection_functions.py:1181, in interactive_move_detection(filepaths, output_dir, fig_dir, sf, baseline_dict, init_params)
#    1179 limb_label = None
#    1180 for channels, side, title, limb_label, png_path in windows:
# -> 1181     _interactive_window(
#    1182         df=df,
#    1183         channels=channels,
#    1184         side=side,
#    1185         sf=sf,
#    1186         results_dict=results_all,
#    1187         window_title=title,
#    1188         init_params=init_params or {},
#    1189         baseline_dict=baseline_dict or {},
#    1190         setup=setup,
#    1191         task=task,
#    1192         limb_label=limb_label,
#    1193         png_path=png_path
#    1194     )
#    1196 # ------------ write JSON (one per file) ------------
#    1197 # channels, that miss in the df → results_all hold only the ones that are present
#    1198 out_path = os.path.join(output_dir, f"{base_noext[:-10]}.json")
#
# File ~\Documents\GitHub\lid_opm\combined_analysis_bachelor\code\movement_detection_functions.py:1100, in _interactive_window(df, channels, side, sf, results_dict, window_title, init_params, baseline_dict, setup, task, limb_label, png_path)
#    1097 # titel
#    1098 plt.suptitle(window_title, fontsize=14)
# -> 1100 plt.show()
#
# File ~\anaconda3\envs\bachelors_clone\Lib\site-packages\matplotlib\pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)    611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\anaconda3\envs\bachelors_clone\Lib\site-packages\matplotlib\backend_bases.py:3547, in _Backend.show(cls, block)
#    3545     block = not ipython_pylab and not is_interactive()
#    3546 if block:
# -> 3547     cls.mainloop()
#
# File ~\anaconda3\envs\bachelors_clone\Lib\site-packages\matplotlib\backends\backend_qt.py:642, in FigureManagerQT.start_main_loop(cls)
#     640 qapp = QtWidgets.QApplication.instance()
#     641 if qapp:
# --> 642     with _allow_interrupt_qt(qapp):
#     643         qt_compat._exec(qapp)
#
# File ~\anaconda3\envs\bachelors_clone\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~\anaconda3\envs\bachelors_clone\Lib\site-packages\matplotlib\backend_bases.py:1658, in _allow_interrupt(prepare_notifier, handle_sigint)
#    1656 signal.signal(signal.SIGINT, old_sigint_handler)
#    1657 if handler_args is not None:
# -> 1658     old_sigint_handler(*handler_args)
#
# KeyboardInterrupt:
