# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mne

# %%
df = pd.read_csv("C:/Users/User/Downloads/test_data_oderso/AB11_emg_2022-11-11_11h55.06.119.csv")

# %%
df
# Out:
#          585.0  339.0   185.0  -243.0  -311.0  -196.0   14.0  292.0  \
# 0        181.0  100.0   496.0   158.0   174.0  -126.0  130.0  -39.0
# 1       -455.0   32.0  -151.0   184.0   365.0    63.0  505.0  -31.0
# 2        -88.0  -77.0  -329.0  -177.0   -81.0    70.0 -143.0   75.0
# 3       -211.0  312.0   -10.0  -119.0   117.0    93.0 -266.0   67.0
# 4        379.0  161.0    92.0   356.0   -98.0   -18.0  -51.0  -80.0
# ...        ...    ...     ...     ...     ...     ...    ...    ...
# 2363891 -134.0   62.0   910.0   375.0   -34.0   495.0  501.0   74.0
# 2363892  162.0  222.0   -63.0   694.0   428.0  -194.0  384.0  281.0
# 2363893  -61.0 -116.0 -1589.0  -588.0  -363.0    95.0 -577.0 -469.0
# 2363894   35.0 -400.0  1422.0 -1031.0   324.0    54.0 -292.0   10.0
# 2363895 -514.0 -343.0  -860.0  -145.0   -54.0   418.0  303.0 -121.0
#
#          1668185713.3213723
# 0              1.668186e+09
# 1              1.668186e+09
# 2              1.668186e+09
# 3              1.668186e+09
# ...

# %%
sampling_rate = 1000  
time = np.arange(0, len(df)) / sampling_rate

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x=time, y=df['585.0'])
plt.xlabel('Time (s)')
plt.ylabel('EMG Amplitude')
plt.title('EMG Signal for random Channel')
plt.show()
